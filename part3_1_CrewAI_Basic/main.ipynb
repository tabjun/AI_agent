# %% [markdown]
# [CrewAI](https://docs.crewai.com/)

# %%
# Crew는 agent들의 그룹이고, agent는 특정 task를 수행하는 독립적인 존재(단위)
'''
Crewai 공부 파일(아주 기초, 완전 사용자 친환경)
Crewai는 진짜 쉽지만, landgraph는 더 자세히 우리가 설정할 수 있지만, Crewai는 완전 세세한 설정은 불가능
Crewai는 agent 유형이 따로 있음. 그건 바로 '기본형', '대화형', '문서요약형' 등이 있음
Crewai는 보통 multi-agent를 만드려고 쓰는 줄 알지만, 오히려 자동화된 작업 흐름을 만드는 게 더 적합함
이걸 설명하기 위해 가장 좋은 예시는 "조립 라인 자동화"임
입력이 하나 들어오면 그걸 조립 라인에 태우고, 그 입력을 변환해서 완전 다른 결과를 얻음
여기서 입력은 뉴스 텍스트, 뉴스 텍스트에서 핵심 문장만 뽑아내고, 그 핵심 문장을 요약해서 최종 결과물을 만드는 것임
'''
